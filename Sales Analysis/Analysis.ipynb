# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Task 1: Merge all Data

# %%
# files = [file for file in os.listdir('./Sales_Data')]

# all_months_data = pd.DataFrame()
                                     
# for file in files:
#     sales_df = pd.read_csv("./Sales_Data/"+file)
#     all_months_data = pd.concat([all_months_data, sales_df])
    
# all_months_data.to_csv("all_data.csv",index = False)

# %%
df = pd.read_csv('all_data.csv')

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1               NaN                                   NaN
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### Clean up the Data

# %% [markdown]
# #### Drop data with NaN

# %%
nan_df = df[df.isna().any(axis = 1)]
nan_df.head()

df = df.dropna(how = 'all')
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Find 'Or' and delete

# %%
df = df[df['Order Date'].str[0:2] != 'Or']
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Convert columns to correct type

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %% [markdown]
# #### Augumented Data with additional columns

# %% [markdown]
# #### Task 2: Add month Column

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
df['Month 2'] = pd.to_datetime(df['Order Date']).dt.month
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  Month 2
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4

# %% [markdown]
# #### Task 3: Add a Sales Column

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  Month 2  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales
# 0   23.90
# 2   99.99
# 3  600.00
# 4   11.99
# 5   11.99

# %% [markdown]
# #### Task 4: Add a city column

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split()[0]

df['City'] = df['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  Month 2  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales               City
# 0   23.90        Dallas (TX)
# 2   99.99        Boston (MA)
# 3  600.00   Los Angeles (CA)
# 4   11.99   Los Angeles (CA)
# 5   11.99   Los Angeles (CA)

# %% [markdown]
# #### Question 1: What was the best month for Sales? How much was earned that month?

# %%
results = df.groupby('Month').sum()
results
# Out:
#        Quantity Ordered  Price Each  Month 2       Sales
# Month
# 1                 10903  1811768.38     9709  1822256.73
# 2                 13449  2188884.72    23950  2202022.42
# 3                 17005  2791207.83    45459  2807100.38
# 4                 20558  3367671.02    73116  3390670.24
# 5                 18667  3135125.13    82830  3152606.75
# 6                 15253  2562025.61    81324  2577802.26
# 7                 16072  2632539.56   100051  2647775.76
# 8                 13448  2230345.42    95688  2244467.88
# 9                 13109  2084992.09   104589  2097560.13
# 10                22703  3715554.83   202820  3736726.88
# 11                19798  3180600.68   193303  3199603.20
# 12                28114  4588415.41   299808  4613443.34

# %%
import matplotlib.pyplot as plt

months = range(1,13)

plt.bar(months, results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in $')
plt.xlabel('Month Number')
plt.show()

# %% [markdown]
# #### Question 2: Which US city had the highest number of Sales?

# %%
result = df.groupby('City').sum()
result
# Out:
#                      Quantity Ordered  Price Each   Month  Month 2       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794   104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829    69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112   141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620   104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325   208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741   175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144    17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621    70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520   315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941   104941  2747755.48

# %%
cities = [city for city, df in df.groupby('City')]
plt.bar(cities, result['Sales'])
plt.xticks(cities, rotation = 'vertical', size = 10)
plt.ylabel('Sales in $')
plt.xlabel('City Name')
plt.show()

# %% [markdown]
# #### What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month  Month 2  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales               City
# 0   23.90        Dallas (TX)
# 2   99.99        Boston (MA)
# 3  600.00   Los Angeles (CA)
# 4   11.99   Los Angeles (CA)
# 5   11.99   Los Angeles (CA)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  Month 2  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4        4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4        4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales               City
# 0   23.90        Dallas (TX)
# 2   99.99        Boston (MA)
# 3  600.00   Los Angeles (CA)
# 4   11.99   Los Angeles (CA)
# 5   11.99   Los Angeles (CA)

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute
df['Seconds'] = df['Order Date'].dt.second
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  Month 2  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4        4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4        4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales               City  Hour  Minute  Seconds
# 0   23.90        Dallas (TX)     8      46        0
# 2   99.99        Boston (MA)    22      30        0
# 3  600.00   Los Angeles (CA)    14      38        0
# 4   11.99   Los Angeles (CA)    14      38        0
# 5   11.99   Los Angeles (CA)     9      27        0

# %%
hours = [hour for hour, df in df.groupby('Hour')]

plt.plot(hours, df.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()


#df.groupby(['Hour']).count()
# My recommendation is around 11 A.M and 7 P.M

# %% [markdown]
# #### What products are most often sold together?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  Month 2  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4        4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4        4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4        4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4        4
#
#     Sales               City  Hour  Minute  Seconds
# 0   23.90        Dallas (TX)     8      46        0
# 2   99.99        Boston (MA)    22      30        0
# 3  600.00   Los Angeles (CA)    14      38        0
# 4   11.99   Los Angeles (CA)    14      38        0
# 5   11.99   Los Angeles (CA)     9      27        0

# %%
dfs = df[df['Order ID'].duplicated(keep = False)]
dfs['Grouped'] = dfs.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = dfs[['Order ID', 'Grouped']].drop_duplicates()
# Out:
# C:\Users\ANKITK~1\AppData\Local\Temp/ipykernel_18912/2323217253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs['Grouped'] = dfs.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split()
    count.update(Counter(combinations(row_list, 2)))
    
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('Charging', 'Cable') 3041
# ('Phone,USB-C', 'Charging') 1348
# ('Phone,USB-C', 'Cable') 1171
# ('iPhone,Lightning', 'Charging') 1007
# ('Google', 'Charging') 999
# ('Google', 'Phone,USB-C') 984
# ('Batteries', '(4-pack)') 960
# ('iPhone,Lightning', 'Cable') 888
# ('Google', 'Cable') 871
# ('Airpods', 'Headphones') 732

# %% [markdown]
# #### Which product sold the most?

# %%
product_group = df.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation = 'vertical', size =10)
plt.show()

# %%
prices = df.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color = 'g')
ax2.plot(keys, prices, color = 'b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color = 'g')
ax2.set_ylabel('Price ($)', color = 'b')
ax1.set_xticklabels(keys, rotation = 'vertical', size = 10)

fig.show()
# Out:
# C:\Users\ANKITK~1\AppData\Local\Temp/ipykernel_18912/1402559675.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(keys, rotation = 'vertical', size = 10)
# C:\Users\ANKITK~1\AppData\Local\Temp/ipykernel_18912/1402559675.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
